# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from planReader.planReader import planReader
import cv2

plan = planReader(config_path='conf.yaml', config_color='colors.yaml', debug=True)

path = '2.png'

im = cv2.imread(path, cv2.IMREAD_COLOR)
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
res = plan.process(im)
print(res)
plt.figure(figsize=(15,15))
plt.imshow(im)
plt.show()
# Out:
# ([array([[[ 1037.,   335.],
#         [ 1079.,   321.],
#         [ 1079.,   371.],
#         [ 1036.,   383.]]], dtype=float32)], 10, array([[  1.28317374e+03,   0.00000000e+00,   8.26615060e+02],
#        [  0.00000000e+00,   1.28336978e+03,   6.05818162e+02],
#        [  0.00000000e+00,   0.00000000e+00,   1.00000000e+00]]), array([  2.05252696e-01,  -5.20737914e-01,  -1.38118710e-04,
#          1.15530765e-03,   3.85818931e-01]))
# [[[  45.1652549   -49.57353104  254.3115203 ]]]
# ([array([[[ 1037.,   335.],
#         [ 1078.,   322.],
#         [ 1079.,   371.],
#         [ 1036.,   383.]]], dtype=float32)], 10, array([[  1.28317374e+03,   0.00000000e+00,   8.26615060e+02],
#        [  0.00000000e+00,   1.28336978e+03,   6.05818162e+02],
#        [  0.00000000e+00,   0.00000000e+00,   1.00000000e+00]]), array([  2.05252696e-01,  -5.20737914e-01,  -1.38118710e-04,
#          1.15530765e-03,   3.85818931e-01]))
# PlayingSide.GREEN
# [[1072  767]
#  [ 960  768]
#  [ 960  828]
#  [1073  832]]
# ['Yellow', 'Green', 'Black']
